# %%
import pandas as pd 
import sys
import os
from format_normal_traffic import DataFrameFormatterNormalTraffic
from format_suricata_df import DataFrameFormatterSuricata


# Get parent of current working directory
parent_dir = os.path.dirname(os.getcwd())
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from df_initializing.handler_init_dfs import DataFrameInitializer
from handler_df_formatter import DataFrameFormatter

# %%
pd.set_option('display.max_rows', None)        # Show all rows
pd.set_option('display.max_columns', None)     # Show all columns
pd.set_option('display.width', None)           # No line wrapping
pd.set_option('display.max_colwidth', None)    # Show full cell content

df_initializer = DataFrameInitializer(
    suricata_json_path='../../data/suricata/log/suricata.json',
    normal_traffic_json_path="../../data/normal_traffic/benign_traffic_fixed.json"
)

df_suricata, df_normal_traffic = df_initializer.initialize_dfs(sample_size=1000)

df_formatter = DataFrameFormatter(df_suricata, df_normal_traffic)


#print("Cowrie Columns:", df_formatter.cowrie_df.info())
#print("Dionea Columns:", df_formatter.dionea_df.info())
print("Suricata Columns:", df_formatter.suricata_df.info())
#print("Normal Traffic Columns:", df_formatter.normal_traffic_df.info())

#df_formatter.dionea_df

#df_formatter.cowrie_df['application_protocol'].value_counts()
#df_formatter.dionea_df['application_protocol'].value_counts()
#df_formatter.suricata_df['application_protocol'].value_counts()
#df_formatter.normal_traffic_df['application_protocol'].value_counts()

# df_formatter.unite_honeypot_and_normal_traffic_dfs()
# df_formatter.unite_all_honeypot_dfs()

#df_dionea["connection"]

df_formatter.suricata_df.head()
df_formatter.normal_traffic_df.head()

df_formatter.normal_traffic_df["direction"].value_counts()
# Out:
# c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_formatting\format_suricata_df.py:45: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   suricata_df_renamed.loc[suricata_df_renamed[self.list_of_features_to_rename[2]].isna(), self.list_of_features_to_rename[2]] = "0.0"
# c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_formatting\format_suricata_df.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   suricata_df_renamed.loc[suricata_df_renamed[self.list_of_features_to_rename[3]].isna(), self.list_of_features_to_rename[3]] = "0.0"
# Fetching geolocation data for 1189 unique IPs...
# Processed 10/1189 IPs...
# Processed 20/1189 IPs...
# Processed 30/1189 IPs...
# Processed 40/1189 IPs...
# Processed 50/1189 IPs...
# Processed 60/1189 IPs...
# Processed 70/1189 IPs...
# Processed 80/1189 IPs...
# Processed 90/1189 IPs...
# Processed 100/1189 IPs...
# Processed 110/1189 IPs...
# Processed 120/1189 IPs...
# Processed 130/1189 IPs...
# Processed 140/1189 IPs...
# Processed 150/1189 IPs...
# Processed 160/1189 IPs...
# Processed 170/1189 IPs...
# Processed 180/1189 IPs...
# Processed 190/1189 IPs...
# Processed 200/1189 IPs...
# Processed 210/1189 IPs...
# Processed 220/1189 IPs...
# Processed 230/1189 IPs...
# Processed 240/1189 IPs...
# Processed 250/1189 IPs...
# Processed 260/1189 IPs...
# Processed 270/1189 IPs...
# Processed 280/1189 IPs...
# Processed 290/1189 IPs...
# Processed 300/1189 IPs...
# Processed 310/1189 IPs...
# Processed 320/1189 IPs...
# Processed 330/1189 IPs...
# Processed 340/1189 IPs...
# Processed 350/1189 IPs...
# Processed 360/1189 IPs...
# Processed 370/1189 IPs...
# Processed 380/1189 IPs...
# Processed 390/1189 IPs...
# Processed 400/1189 IPs...
# Processed 410/1189 IPs...
# Processed 420/1189 IPs...
# Processed 430/1189 IPs...
# Processed 440/1189 IPs...
# Processed 450/1189 IPs...
# Processed 460/1189 IPs...
# Processed 470/1189 IPs...
# Processed 480/1189 IPs...
# Processed 490/1189 IPs...
# Processed 500/1189 IPs...
# Processed 510/1189 IPs...
# Processed 520/1189 IPs...
# Processed 530/1189 IPs...
# Processed 540/1189 IPs...
# Processed 550/1189 IPs...
# Processed 560/1189 IPs...
# Processed 570/1189 IPs...
# Processed 580/1189 IPs...
# Processed 590/1189 IPs...
# Processed 600/1189 IPs...
# Processed 610/1189 IPs...
# Processed 620/1189 IPs...
# Processed 630/1189 IPs...
# Processed 640/1189 IPs...
# Processed 650/1189 IPs...
# Processed 660/1189 IPs...
# Processed 670/1189 IPs...
# Processed 680/1189 IPs...
# Processed 690/1189 IPs...
# Processed 700/1189 IPs...
# Processed 710/1189 IPs...
# Processed 720/1189 IPs...
# Processed 730/1189 IPs...
# Processed 740/1189 IPs...
# Processed 750/1189 IPs...
# Processed 760/1189 IPs...
# Processed 770/1189 IPs...
# Processed 780/1189 IPs...
# Processed 790/1189 IPs...
# Processed 800/1189 IPs...
# Processed 810/1189 IPs...
# Processed 820/1189 IPs...
# Processed 830/1189 IPs...
# Processed 840/1189 IPs...
# Processed 850/1189 IPs...
# Processed 860/1189 IPs...
# Processed 870/1189 IPs...
# Processed 880/1189 IPs...
# Processed 890/1189 IPs...
# Processed 900/1189 IPs...
# Processed 910/1189 IPs...
# Processed 920/1189 IPs...
# Processed 930/1189 IPs...
# Processed 940/1189 IPs...
# Processed 950/1189 IPs...
# Processed 960/1189 IPs...
# Processed 970/1189 IPs...
# Processed 980/1189 IPs...
# Processed 990/1189 IPs...
# Processed 1000/1189 IPs...
# Processed 1010/1189 IPs...
# Processed 1020/1189 IPs...
# Processed 1030/1189 IPs...
# Processed 1040/1189 IPs...
# Processed 1050/1189 IPs...
# Processed 1060/1189 IPs...
# Processed 1070/1189 IPs...
# Processed 1080/1189 IPs...
# Processed 1090/1189 IPs...
# Processed 1100/1189 IPs...
# Processed 1110/1189 IPs...
# Processed 1120/1189 IPs...
# Processed 1130/1189 IPs...
# Processed 1140/1189 IPs...
# Processed 1150/1189 IPs...
# Processed 1160/1189 IPs...
# Processed 1170/1189 IPs...
# Processed 1180/1189 IPs...
# Geolocation lookup complete!
# Fetching geolocation data for 223 unique destination IPs...
# Processed 10/223 destination IPs...
# Processed 20/223 destination IPs...
# Processed 30/223 destination IPs...
# Processed 40/223 destination IPs...
# Processed 50/223 destination IPs...
# Processed 60/223 destination IPs...
# Processed 70/223 destination IPs...
# Processed 80/223 destination IPs...
# Processed 90/223 destination IPs...
# Processed 100/223 destination IPs...
# Processed 110/223 destination IPs...
# Processed 120/223 destination IPs...
# Processed 130/223 destination IPs...
# Processed 140/223 destination IPs...
# Processed 150/223 destination IPs...
# Processed 160/223 destination IPs...
# Processed 170/223 destination IPs...
# Processed 180/223 destination IPs...
# Processed 190/223 destination IPs...
# Processed 200/223 destination IPs...
# Processed 210/223 destination IPs...
# Processed 220/223 destination IPs...
# Destination IP geolocation lookup complete!
# Fetching geolocation data for 26 unique IPs...
# Processed 10/26 IPs...
# Processed 20/26 IPs...
# Geolocation lookup complete!
# Fetching geolocation data for 156 unique destination IPs...
# Processed 10/156 destination IPs...
# Processed 20/156 destination IPs...
# Processed 30/156 destination IPs...
# Processed 40/156 destination IPs...
# Processed 50/156 destination IPs...
# Processed 60/156 destination IPs...
# Processed 70/156 destination IPs...
# Processed 80/156 destination IPs...
# Processed 90/156 destination IPs...
# Processed 100/156 destination IPs...
# Processed 110/156 destination IPs...
# Processed 120/156 destination IPs...
# Processed 130/156 destination IPs...
# Processed 140/156 destination IPs...
# Processed 150/156 destination IPs...
# Destination IP geolocation lookup complete!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71679 entries, 0 to 71678
# Data columns (total 43 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   source_ip             71679 non-null  object
#  1   destination_ip        71679 non-null  object
#  2   source_port           71679 non-null  Int64
#  3   destination_port      71679 non-null  Int64
#  4   timestamp_start       71679 non-null  datetime64[ns]
#  5   transport_protocol    71679 non-null  object
#  6   application_protocol  71679 non-null  object
#  7   duration              71679 non-null  float64
#  8   bytes_sent            71679 non-null  int64
#  9   bytes_received        71679 non-null  int64
#  10  pkts_sent             71679 non-null  int64
#  11  pkts_received         71679 non-null  int64
#  12  direction             71679 non-null  object
#  13  label                 71679 non-null  object
#  14  bytes_per_second      71679 non-null  float64
#  15  packets_per_second    71679 non-null  float64
#  16  bytes_per_packet      71679 non-null  float64
#  17  bytes_sent_ratio      71679 non-null  float64
#  18  packets_sent_ratio    71679 non-null  float64
#  19  hour                  71679 non-null  int32
#  20  day_of_week           71679 non-null  int32
#  21  is_weekend            71679 non-null  int64
#  22  is_business_hours     71679 non-null  int64
#  23  src_is_private        71679 non-null  int64
#  24  dst_is_private        71679 non-null  int64
#  25  is_internal           71679 non-null  int64
#  26  dst_port_is_common    71679 non-null  int64
#  27  src_ip_type           49908 non-null  object
#  28  src_continent         49908 non-null  object
#  29  src_country           49908 non-null  object
#  30  src_region            49908 non-null  object
#  31  src_city              49908 non-null  object
#  32  src_latitude          49908 non-null  float64
#  33  src_longitude         49908 non-null  float64
#  34  src_isp               49908 non-null  object
#  35  dst_ip_type           10952 non-null  object
#  36  dst_continent         10952 non-null  object
#  37  dst_country           10952 non-null  object
#  38  dst_region            10952 non-null  object
#  39  dst_city              10952 non-null  object
#  40  dst_latitude          10952 non-null  float64
#  41  dst_longitude         10952 non-null  float64
#  42  dst_isp               10952 non-null  object
# dtypes: Int64(2), datetime64[ns](1), float64(10), int32(2), int64(10), object(18)
# memory usage: 23.1+ MB
# Suricata Columns: None
# direction
# L2L    513
# L2R    481
# R2L      4
# R2R      2
# Name: count, dtype: int64

# %%
df_formatter.suricata_df.head()
# Out:
#          source_ip  destination_ip  source_port  destination_port  \
# 0    16.62.107.190      10.128.0.2            0                 0
# 1  169.254.169.254      10.128.0.2           53             36113
# 2       10.128.0.2  216.239.34.174        59728               443
# 3       10.128.0.2  216.239.34.174        53790               443
# 4   216.239.34.174      10.128.0.2          443             53790
#
#              timestamp_start transport_protocol application_protocol  \
# 0 2025-10-24 02:44:06.405778               icmp              unknown
# 1 2025-10-24 02:44:07.619878                udp               failed
# 2 2025-10-24 02:44:07.623239                tcp              unknown
# 3 2025-10-24 02:44:08.117768                tcp              unknown
# 4 2025-10-24 02:44:08.118390                tcp              unknown
#
#    duration  bytes_sent  bytes_received  pkts_sent  pkts_received direction  \
# 0  0.000000          82               0          1              0       L2R
# 1  0.000592         164             172          2              1       R2L
# 2  0.000000           0               0          0              0   unknown
# 3  0.000123         156               0          2              0       L2R
# 4  0.000745         156              66          2              1       R2L
#
#        label  bytes_per_second  packets_per_second  bytes_per_packet  \
# 0  malicious      0.000000e+00            0.000000              82.0
# 1  malicious      5.675676e+05         5067.567568             112.0
# 2  malicious      0.000000e+00            0.000000               0.0
# 3  malicious      1.268293e+06        16260.162602              78.0
# 4  malicious      2.979866e+05         4026.845638              74.0
#
#    bytes_sent_ratio  packets_sent_ratio  hour  day_of_week  is_weekend  \
# 0          1.000000            1.000000     2            4           0
# 1          0.488095            0.666667     2            4           0
# 2          0.000000            0.000000     2            4           0
# 3          1.000000            1.000000     2            4           0
# 4          0.702703            0.666667     2            4           0
#
#    is_business_hours  src_is_private  dst_is_private  is_internal  \
# 0                  0               0               1            0
# 1                  0               1               1            1
# 2                  0               1               0            0
# 3                  0               1               0            0
# 4                  0               0               1            0
#
#    dst_port_is_common src_ip_type  src_continent    src_country  src_region  \
# 0                   0        IPv4         Europe    Switzerland      Zurich
# 1                   0        None           None           None        None
# 2                   1        None           None           None        None
# 3                   1        None           None           None        None
# 4                   0        IPv4  North America  United States  California
#
#         src_city  src_latitude  src_longitude           src_isp dst_ip_type  \
# 0         Zürich     47.376887       8.541694  Amazon.com, Inc.        None
# 1           None           NaN            NaN              None        None
# 2           None           NaN            NaN              None        IPv4
# 3           None           NaN            NaN              None        IPv4
# 4  Mountain View     37.386052    -122.083851        Google LLC        None
#
#    dst_continent    dst_country  dst_region       dst_city  dst_latitude  \
# 0           None           None        None           None           NaN
# 1           None           None        None           None           NaN
# 2  North America  United States  California  Mountain View     37.386052
# 3  North America  United States  California  Mountain View     37.386052
# 4           None           None        None           None           NaN
#
#    dst_longitude     dst_isp
# 0            NaN        None
# 1            NaN        None
# 2    -122.083851  Google LLC
# 3    -122.083851  Google LLC
# 4            NaN        None

# %%
df_formatter.normal_traffic_df.head()
# Out:
#        source_ip   destination_ip  source_port  destination_port  \
# 0  192.168.5.122      224.0.0.251         5353              5353
# 1  192.168.2.111  206.217.198.186         4435                80
# 2  192.168.4.119    192.168.5.122         4428                53
# 3  192.168.4.119   219.94.203.105         3639                80
# 4  192.168.4.119     98.137.80.50         3641                80
#
#       timestamp_start transport_protocol application_protocol  duration  \
# 0 2010-06-13 23:57:00                udp          unknown_udp     840.0
# 1 2010-06-13 23:58:00                tcp    httpimagetransfer     180.0
# 2 2010-06-13 23:58:00                udp                  dns      60.0
# 3 2010-06-13 23:58:00                tcp    httpimagetransfer     120.0
# 4 2010-06-13 23:58:00                tcp    httpimagetransfer      60.0
#
#    bytes_sent  bytes_received  pkts_sent  pkts_received direction   label  \
# 0       16076               0        178              0       L2R  benign
# 1         384               0          6              0       L2R  benign
# 2         171             642          2              4       L2L  benign
# 3         384               0          6              0       L2R  benign
# 4         186             128          2              2       L2R  benign
#
#    bytes_per_second  packets_per_second  bytes_per_packet  bytes_sent_ratio  \
# 0         19.138095            0.211905         90.314607          1.000000
# 1          2.133333            0.033333         64.000000          1.000000
# 2         13.550000            0.100000        135.500000          0.210332
# 3          3.200000            0.050000         64.000000          1.000000
# 4          5.233333            0.066667         78.500000          0.592357
#
#    packets_sent_ratio  hour  day_of_week  is_weekend  is_business_hours  \
# 0            1.000000    23            6           1                  0
# 1            1.000000    23            6           1                  0
# 2            0.333333    23            6           1                  0
# 3            1.000000    23            6           1                  0
# 4            0.500000    23            6           1                  0
#
#    src_is_private  dst_is_private  is_internal  dst_port_is_common  \
# 0               1               0            0                   0
# 1               1               0            0                   1
# 2               1               1            1                   1
# 3               1               0            0                   1
# 4               1               0            0                   1
#
#   src_ip_type src_continent src_country src_region src_city  src_latitude  \
# 0        None          None        None       None     None           NaN
# 1        None          None        None       None     None           NaN
# 2        None          None        None       None     None           NaN
# 3        None          None        None       None     None           NaN
# 4        None          None        None       None     None           NaN
#
#    src_longitude src_isp dst_ip_type  dst_continent    dst_country  \
# 0            NaN    None        None           None           None
# 1            NaN    None        IPv4  North America  United States
# 2            NaN    None        None           None           None
# 3            NaN    None        IPv4           Asia          Japan
# 4            NaN    None        IPv4  North America  United States
#
#          dst_region  dst_city  dst_latitude  dst_longitude  \
# 0              None      None           NaN            NaN
# 1          New York  New York     40.712784     -74.005941
# 2              None      None           NaN            NaN
# 3  Osaka Prefecture     Osaka     34.693738     135.502165
# 4          Nebraska     Omaha     41.252363     -95.997988
#
#                 dst_isp
# 0                  None
# 1            Uk Limited
# 2                  None
# 3  Sakura Internet Inc.
# 4   Yahoo Holdings Inc.

# %%
print(df_formatter.suricata_df.info())
print(df_formatter.normal_traffic_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71679 entries, 0 to 71678
# Data columns (total 43 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   source_ip             71679 non-null  object
#  1   destination_ip        71679 non-null  object
#  2   source_port           71679 non-null  Int64
#  3   destination_port      71679 non-null  Int64
#  4   timestamp_start       71679 non-null  datetime64[ns]
#  5   transport_protocol    71679 non-null  object
#  6   application_protocol  71679 non-null  object
#  7   duration              71679 non-null  float64
#  8   bytes_sent            71679 non-null  int64
#  9   bytes_received        71679 non-null  int64
#  10  pkts_sent             71679 non-null  int64
#  11  pkts_received         71679 non-null  int64
#  12  direction             71679 non-null  object
#  13  label                 71679 non-null  object
#  14  bytes_per_second      71679 non-null  float64
#  15  packets_per_second    71679 non-null  float64
#  16  bytes_per_packet      71679 non-null  float64
#  17  bytes_sent_ratio      71679 non-null  float64
#  18  packets_sent_ratio    71679 non-null  float64
#  19  hour                  71679 non-null  int32
#  20  day_of_week           71679 non-null  int32
#  21  is_weekend            71679 non-null  int64
#  22  is_business_hours     71679 non-null  int64
#  23  src_is_private        71679 non-null  int64
#  24  dst_is_private        71679 non-null  int64
#  25  is_internal           71679 non-null  int64
#  26  dst_port_is_common    71679 non-null  int64
#  27  src_ip_type           49908 non-null  object
#  28  src_continent         49908 non-null  object
#  29  src_country           49908 non-null  object
#  30  src_region            49908 non-null  object
#  31  src_city              49908 non-null  object
#  32  src_latitude          49908 non-null  float64
#  33  src_longitude         49908 non-null  float64
#  34  src_isp               49908 non-null  object
#  35  dst_ip_type           10952 non-null  object
#  36  dst_continent         10952 non-null  object
#  37  dst_country           10952 non-null  object
#  38  dst_region            10952 non-null  object
#  39  dst_city              10952 non-null  object
#  40  dst_latitude          10952 non-null  float64
#  41  dst_longitude         10952 non-null  float64
#  42  dst_isp               10952 non-null  object
# dtypes: Int64(2), datetime64[ns](1), float64(10), int32(2), int64(10), object(18)
# memory usage: 23.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 43 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   source_ip             1000 non-null   object
#  1   destination_ip        1000 non-null   object
#  2   source_port           1000 non-null   int64
#  3   destination_port      1000 non-null   int64
#  4   timestamp_start       1000 non-null   datetime64[ns]
#  5   transport_protocol    1000 non-null   object
#  6   application_protocol  1000 non-null   object
#  7   duration              1000 non-null   float64
#  8   bytes_sent            1000 non-null   int64
#  9   bytes_received        1000 non-null   int64
#  10  pkts_sent             1000 non-null   int64
#  11  pkts_received         1000 non-null   int64
#  12  direction             1000 non-null   object
#  13  label                 1000 non-null   object
#  14  bytes_per_second      1000 non-null   float64
#  15  packets_per_second    1000 non-null   float64
#  16  bytes_per_packet      1000 non-null   float64
#  17  bytes_sent_ratio      1000 non-null   float64
#  18  packets_sent_ratio    1000 non-null   float64
#  19  hour                  1000 non-null   int32
#  20  day_of_week           1000 non-null   int32
#  21  is_weekend            1000 non-null   int64
#  22  is_business_hours     1000 non-null   int64
#  23  src_is_private        1000 non-null   int64
#  24  dst_is_private        1000 non-null   int64
#  25  is_internal           1000 non-null   int64
#  26  dst_port_is_common    1000 non-null   int64
#  27  src_ip_type           4 non-null      object
#  28  src_continent         4 non-null      object
#  29  src_country           4 non-null      object
#  30  src_region            4 non-null      object
#  31  src_city              4 non-null      object
#  32  src_latitude          4 non-null      float64
#  33  src_longitude         4 non-null      float64
#  34  src_isp               4 non-null      object
#  35  dst_ip_type           480 non-null    object
#  36  dst_continent         480 non-null    object
#  37  dst_country           480 non-null    object
#  38  dst_region            480 non-null    object
#  39  dst_city              480 non-null    object
#  40  dst_latitude          480 non-null    float64
#  41  dst_longitude         480 non-null    float64
#  42  dst_isp               480 non-null    object
# dtypes: datetime64[ns](1), float64(10), int32(2), int64(12), object(18)
# memory usage: 328.3+ KB
# None

# %%
import requests

def get_location(ip_address="161.185.160.93"):
    response = requests.get(f'https://ipapi.co/{ip_address}/json/').json()
    location_data = {
        "ip": ip_address,
        "city": response.get("city"),
        "region": response.get("region"),
        "country": response.get("country_name")
    }
    return location_data

location_info = get_location("161.185.160.93")
print(location_info)
# Out:
# {'ip': '161.185.160.93', 'city': None, 'region': None, 'country': None}

# %%
import requests

ip = "8.8.8.8"
url = f"https://ipwho.is/{ip}"

response = requests.get(url).json()

print(response)
# Out:
# {'ip': '8.8.8.8', 'success': True, 'type': 'IPv4', 'continent': 'North America', 'continent_code': 'NA', 'country': 'United States', 'country_code': 'US', 'region': 'California', 'region_code': 'CA', 'city': 'Mountain View', 'latitude': 37.3860517, 'longitude': -122.0838511, 'is_eu': False, 'postal': '94039', 'calling_code': '1', 'capital': 'Washington D.C.', 'borders': 'CA,MX', 'flag': {'img': 'https://cdn.ipwhois.io/flags/us.svg', 'emoji': '🇺🇸', 'emoji_unicode': 'U+1F1FA U+1F1F8'}, 'connection': {'asn': 15169, 'org': 'Google LLC', 'isp': 'Google LLC', 'domain': 'google.com'}, 'timezone': {'id': 'America/Los_Angeles', 'abbr': 'PST', 'is_dst': False, 'offset': -28800, 'utc': '-08:00', 'current_time': '2025-11-21T09:09:26-08:00'}}
