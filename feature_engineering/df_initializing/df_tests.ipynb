# %%
from handler_init_dfs import DataFrameInitializer
import os

# Verify current working directory
print("Current working directory:", os.getcwd())

df_initializer = DataFrameInitializer(
    cowrie_json_path='../../data/cowrie/log/cowrie.json',
    dionea_json_path='../../data/dionaea/log/dionaea.json',
    suricata_json_path='../../data/suricata/log/suricata.json',
    normal_traffic_json_path="../../data/normal_traffic/benign_traffic_fixed.json"
)

df_cowrie, df_dionea, df_suricata, df_normal_traffic = df_initializer.initialize_dfs()

df_normal_traffic.head()
# Out:
# Current working directory: c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_initializing
#          generated            appName  totalSourceBytes  \
# 0  3/11/2014 18:21        Unknown_UDP             16076
# 1  3/11/2014 18:21  HTTPImageTransfer               384
# 2  3/11/2014 18:21                DNS               171
# 3  3/11/2014 18:21  HTTPImageTransfer               384
# 4  3/11/2014 18:21  HTTPImageTransfer               186
#
#    totalDestinationBytes  totalDestinationPackets  totalSourcePackets  \
# 0                      0                        0                 178
# 1                      0                        0                   6
# 2                    642                        4                   2
# 3                      0                        0                   6
# 4                    128                        2                   2
#
#   sourcePayloadAsBase64 sourcePayloadAsUTF destinationPayloadAsBase64  \
# 0                  None               None                       None
# 1                  None               None                       None
# 2                  None               None                       None
# 3                  None               None                       None
# 4                  None               None                       None
#
#   destinationPayloadAsUTF  ... sourceTCPFlagsDescription  \
# 0                    None  ...                      None
# 1                    None  ...                       F,A
# 2                    None  ...                      None
# 3                    None  ...                       F,A
# 4                    None  ...                     F,P,A
#
#   destinationTCPFlagsDescription         source protocolName sourcePort  \
# 0                           None  192.168.5.122       udp_ip       5353
# 1                           None  192.168.2.111       tcp_ip       4435
# 2                           None  192.168.4.119       udp_ip       4428
# 3                           None  192.168.4.119       tcp_ip       3639
# 4                              R  192.168.4.119       tcp_ip       3641
#
#        destination destinationPort    startDateTime     stopDateTime   Label
# 0      224.0.0.251            5353  6/13/2010 23:57   6/14/2010 0:11  Normal
# 1  206.217.198.186              80  6/13/2010 23:58   6/14/2010 0:01  Normal
# 2    192.168.5.122              53  6/13/2010 23:58  6/13/2010 23:59  Normal
# 3   219.94.203.105              80  6/13/2010 23:58   6/14/2010 0:00  Normal
# 4     98.137.80.50              80  6/13/2010 23:58  6/13/2010 23:59  Normal
#
# [5 rows x 21 columns]

# %%
import sys
import os
import pandas as pd
import pandas as pd

# Add parent directory to path to access sibling folder
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../df_formatting'))

from handler_init_dfs import DataFrameInitializer

pd.set_option('display.max_rows', None)        # Show all rows
pd.set_option('display.max_columns', None)     # Show all columns
pd.set_option('display.width', None)           # No line wrapping
pd.set_option('display.max_colwidth', None)    # Show full cell content


df_initializer = DataFrameInitializer(
    cowrie_json_path='../../data/cowrie/log/cowrie.json',
    dionea_json_path='../../data/dionaea/log/dionaea.json',
    suricata_json_path='../../data/suricata/log/suricata.json',
    normal_traffic_json_path="../../data/normal_traffic/benign_traffic_fixed.json"
)

df_cowrie, df_dionea, df_suricata, df_normal_traffic = df_initializer.initialize_dfs(sample_size=1000)

df_normal_traffic.head()
# Out:
#          generated            appName  totalSourceBytes  \
# 0  3/11/2014 18:21        Unknown_UDP             16076
# 1  3/11/2014 18:21  HTTPImageTransfer               384
# 2  3/11/2014 18:21                DNS               171
# 3  3/11/2014 18:21  HTTPImageTransfer               384
# 4  3/11/2014 18:21  HTTPImageTransfer               186
#
#    totalDestinationBytes  totalDestinationPackets  totalSourcePackets  \
# 0                      0                        0                 178
# 1                      0                        0                   6
# 2                    642                        4                   2
# 3                      0                        0                   6
# 4                    128                        2                   2
#
#   sourcePayloadAsBase64 sourcePayloadAsUTF destinationPayloadAsBase64  \
# 0                  None               None                       None
# 1                  None               None                       None
# 2                  None               None                       None
# 3                  None               None                       None
# 4                  None               None                       None
#
#   destinationPayloadAsUTF direction sourceTCPFlagsDescription  \
# 0                    None       L2R                      None
# 1                    None       L2R                       F,A
# 2                    None       L2L                      None
# 3                    None       L2R                       F,A
# 4                    None       L2R                     F,P,A
#
#   destinationTCPFlagsDescription         source protocolName  sourcePort  \
# 0                           None  192.168.5.122       udp_ip        5353
# 1                           None  192.168.2.111       tcp_ip        4435
# 2                           None  192.168.4.119       udp_ip        4428
# 3                           None  192.168.4.119       tcp_ip        3639
# 4                              R  192.168.4.119       tcp_ip        3641
#
#        destination  destinationPort    startDateTime     stopDateTime   Label
# 0      224.0.0.251             5353  6/13/2010 23:57   6/14/2010 0:11  Normal
# 1  206.217.198.186               80  6/13/2010 23:58   6/14/2010 0:01  Normal
# 2    192.168.5.122               53  6/13/2010 23:58  6/13/2010 23:59  Normal
# 3   219.94.203.105               80  6/13/2010 23:58   6/14/2010 0:00  Normal
# 4     98.137.80.50               80  6/13/2010 23:58  6/13/2010 23:59  Normal
