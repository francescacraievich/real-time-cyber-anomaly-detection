# %%
from handler_init_dfs import DataFrameInitializer
import os

# Verify current working directory
print("Current working directory:", os.getcwd())

df_initializer = DataFrameInitializer(
    cowrie_json_path='../../data/cowrie/log/cowrie.json',
    dionea_json_path='../../data/dionaea/log/dionaea.json',
    suricata_json_path='../../data/suricata/log/suricata.json',
    normal_traffic_json_path="../../data/normal_traffic/benign_traffic_fixed.json"
)

df_cowrie, df_dionea, df_suricata, df_normal_traffic = df_initializer.initialize_dfs()
print("Cowrie DataFrame:" , df_cowrie.head())
print("Dionea DataFrame:" , df_dionea.head())
print("Suricata DataFrame:" , df_suricata.head())
print("Normal Traffic DataFrame:" , df_normal_traffic.head())

# %%
from handler_init_dfs import DataFrameInitializer

df_initializer = DataFrameInitializer(
    cowrie_json_path='data/cowrie/log/cowrie.json',
    dionea_json_path='data/dionaea/log/dionaea.json',
    suricata_json_path='data/suricata/log/suricata.json',
    normal_traffic_json_path="data/normal_traffic/benign_traffic_fixed.json"
)
df_cowrie, df_dionea, df_suricata, df_normal_traffic = df_initializer.initialize_dfs()
print("Cowrie DataFrame:" , df_cowrie.head())
print("Dionea DataFrame:" , df_dionea.head())
print("Suricata DataFrame:" , df_suricata.head())
print("Normal Traffic DataFrame:" , df_normal_traffic.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       1 from handler_init_dfs import DataFrameInitializer
#       3 df_initializer = DataFrameInitializer(
#       4     cowrie_json_path='data/cowrie/log/cowrie.json',
#       5     dionea_json_path='data/dionaea/log/dionaea.json',
#       6     suricata_json_path='data/suricata/log/suricata.json',
#       7     normal_traffic_json_path="data/normal_traffic/benign_traffic_fixed.json"
#       8 )
# ----> 9 df_cowrie, df_dionea, df_suricata, df_normal_traffic = df_initializer.initialize_dfs()
#      10 print("Cowrie DataFrame:" , df_cowrie.head())
#      11 print("Dionea DataFrame:" , df_dionea.head())
#
# File c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_initializing\handler_init_dfs.py:30, in DataFrameInitializer.initialize_dfs(self, preprocess_normal_traffic)
#      29 def initialize_dfs(self, preprocess_normal_traffic=False):
# ---> 30     df_cowrie = self.cowrie_init.initialize_cowrie()
#      31     df_dionea = self.dionea_init.initialize_dionea()
#      32     df_suricata = self.suricata_init.initialize_suricata()
#
# File c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_initializing\init_cowrie_df.py:16, in CowrieDataFrameInitializer.initialize_cowrie(self)
#      14 def initialize_cowrie(self):
#      15     records_Cowrie = []
# ---> 16     with open(self.cowrie_json_path, 'r') as f:
#      17         for line in f:
#      18             records_Cowrie.append(json.loads(line))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cowrie/log/cowrie.json'
