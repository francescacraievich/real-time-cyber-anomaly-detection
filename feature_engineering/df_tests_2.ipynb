# %%
from df_initializing.handler_init_dfs import DataFrameInitializer
from df_formatting.df_formatter import DataFrameFormatter


df_initializer = DataFrameInitializer(
    cowrie_json_path='../data/cowrie/log/cowrie.json',
    dionea_json_path='../data/dionaea/log/dionaea.json',
    suricata_json_path='../data/suricata/log/suricata.json',
    normal_traffic_json_path="../data/normal_traffic/benign_traffic_fixed.json"
)

df_cowrie, df_dionea, df_suricata, df_normal_traffic = df_initializer.initialize_dfs(sample_size=1000)

df_formatter = DataFrameFormatter(cowrie_df=df_cowrie)

df_cowrie_formatted = df_formatter.format_cowrie_df()

df_cowrie_formatted.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from df_initializing.handler_init_dfs import DataFrameInitializer
#       2 from df_formatting.df_formatter import DataFrameFormatter
#       5 df_initializer = DataFrameInitializer(
#       6     cowrie_json_path='../data/cowrie/log/cowrie.json',
#       7     dionea_json_path='../data/dionaea/log/dionaea.json',
#       8     suricata_json_path='../data/suricata/log/suricata.json',
#       9     normal_traffic_json_path="../data/normal_traffic/benign_traffic_fixed.json"
#      10 )
#
# File c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_initializing\handler_init_dfs.py:4
#       2 import pandas as pd
#       3 import gzip
# ----> 4 from init_dionea_df import DioneaDataFrameInitializer as DioneaInit
#       5 from init_suricata_df import SuricataDataFrameInitializer as SuricataInit
#       6 from init_cowrie_df import CowrieDataFrameInitializer as CowrieInit
#
# ModuleNotFoundError: No module named 'init_dionea_df'
