# %%
from feature_engineering.df_initializing.init_normal_traffic_df import NormalTrafficDataFrameInitializer
import os
from feature_engineering.df_initializing.handler_init_dfs import DataFrameInitializer as df_init
from feature_engineering.df_initializing.init_cowrie_df import CowrieDataFrameInitializer

df_initializer = df_init(
    cowrie_json_path='data/cowrie/log/cowrie.json',
    dionea_json_path='data/dionaea/log/dionaea.json',
    suricata_json_path='data/suricata/log/suricata.json',
    normal_traffic_json_path="data/normal_traffic/benign_traffic.json"
)

print(os.getcwd())

df_cowrie, df_dionea, df_suricata = df_initializer.initialize_dfs()
# Out:
# c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#       5 df_initializer = df_init(
#       6     cowrie_json_path='data/cowrie/log/cowrie.json',
#       7     dionea_json_path='data/dionaea/log/dionaea.json',
#       8     suricata_json_path='data/suricata/log/suricata.json',
#       9     normal_traffic_json_path="data/normal_traffic/benign_traffic.json"
#      10 )
#      12 print(os.getcwd())
# ---> 14 df_cowrie, df_dionea, df_suricata = df_initializer.initialize_dfs()
#
# File c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_initializing\handler_init_dfs.py:34, in DataFrameInitializer.initialize_dfs(self)
#      31 df_dionea = self.dionea_init.initialize_dionea()
#      32 df_suricata = self.suricata_init.initialize_suricata()
# ---> 34 self.normal_traffic_init.preprocess_json_replace_invalid_numbers(output_path="data/normal_traffic/benign_traffic_fixed.json")
#      36 # df_normal_traffic = self.initialize_normal_traffic()
#      37 return df_cowrie, df_dionea, df_suricata
#
# File c:\Users\franc\OneDrive\Desktop\Magistrale\Data_Driven_System_Engineering\real-time-cyber-anomaly-detection\feature_engineering\df_initializing\init_normal_traffic_df.py:50, in NormalTrafficDataFrameInitializer.preprocess_json_replace_invalid_numbers(self, output_path)
#      47     for line in f_in:
#      48         # replace NaN, Infinity, -Infinity with null
#      49         line_fixed = re.sub(r'\bNaN\b|\bInfinity\b|\b-Infinity\b', 'null', line)
# ---> 50         f_out.write(line_fixed)
#      51 self.benign_traffic_json_path = output_path
#
# KeyboardInterrupt:

# %%
# Out:
# [{'generated': '3/11/2014 18:21', 'appName': 'Unknown_UDP', 'totalSourceBytes': 16076, 'totalDestinationBytes': 0, 'totalDestinationPackets': 0, 'totalSourcePackets': 178, 'sourcePayloadAsBase64': None, 'sourcePayloadAsUTF': None, 'destinationPayloadAsBase64': None, 'destinationPayloadAsUTF': None, 'direction': 'L2R', 'sourceTCPFlagsDescription': None, 'destinationTCPFlagsDescription': None, 'source': '192.168.5.122', 'protocolName': 'udp_ip', 'sourcePort': 5353, 'destination': '224.0.0.251', 'destinationPort': 5353, 'startDateTime': '6/13/2010 23:57', 'stopDateTime': '6/14/2010 0:11', 'Label': 'Normal'}, {'generated': '3/11/2014 18:21', 'appName': 'HTTPImageTransfer', 'totalSourceBytes': 384, 'totalDestinationBytes': 0, 'totalDestinationPackets': 0, 'totalSourcePackets': 6, 'sourcePayloadAsBase64': None, 'sourcePayloadAsUTF': None, 'destinationPayloadAsBase64': None, 'destinationPayloadAsUTF': None, 'direction': 'L2R', 'sourceTCPFlagsDescription': 'F,A', 'destinationTCPFlagsDescription': None, 'source': '192.168.2.111', 'protocolName': 'tcp_ip', 'sourcePort': 4435, 'destination': '206.217.198.186', 'destinationPort': 80, 'startDateTime': '6/13/2010 23:58', 'stopDateTime': '6/14/2010 0:01', 'Label': 'Normal'}, {'generated': '3/11/2014 18:21', 'appName': 'DNS', 'totalSourceBytes': 171, 'totalDestinationBytes': 642, 'totalDestinationPackets': 4, 'totalSourcePackets': 2, 'sourcePayloadAsBase64': None, 'sourcePayloadAsUTF': None, 'destinationPayloadAsBase64': None, 'destinationPayloadAsUTF': None, 'direction': 'L2L', 'sourceTCPFlagsDescription': None, 'destinationTCPFlagsDescription': None, 'source': '192.168.4.119', 'protocolName': 'udp_ip', 'sourcePort': 4428, 'destination': '192.168.5.122', 'destinationPort': 53, 'startDateTime': '6/13/2010 23:58', 'stopDateTime': '6/13/2010 23:59', 'Label': 'Normal'}, {'generated': '3/11/2014 18:21', 'appName': 'HTTPImageTransfer', 'totalSourceBytes': 384, 'totalDestinationBytes': 0, 'totalDestinationPackets': 0, 'totalSourcePackets': 6, 'sourcePayloadAsBase64': None, 'sourcePayloadAsUTF': None, 'destinationPayloadAsBase64': None, 'destinationPayloadAsUTF': None, 'direction': 'L2R', 'sourceTCPFlagsDescription': 'F,A', 'destinationTCPFlagsDescription': None, 'source': '192.168.4.119', 'protocolName': 'tcp_ip', 'sourcePort': 3639, 'destination': '219.94.203.105', 'destinationPort': 80, 'startDateTime': '6/13/2010 23:58', 'stopDateTime': '6/14/2010 0:00', 'Label': 'Normal'}, {'generated': '3/11/2014 18:21', 'appName': 'HTTPImageTransfer', 'totalSourceBytes': 186, 'totalDestinationBytes': 128, 'totalDestinationPackets': 2, 'totalSourcePackets': 2, 'sourcePayloadAsBase64': None, 'sourcePayloadAsUTF': None, 'destinationPayloadAsBase64': None, 'destinationPayloadAsUTF': None, 'direction': 'L2R', 'sourceTCPFlagsDescription': 'F,P,A', 'destinationTCPFlagsDescription': 'R', 'source': '192.168.4.119', 'protocolName': 'tcp_ip', 'sourcePort': 3641, 'destination': '98.137.80.50', 'destinationPort': 80, 'startDateTime': '6/13/2010 23:58', 'stopDateTime': '6/13/2010 23:59', 'Label': 'Normal'}, {'generated': '3/11/2014 18:21', 'appName': 'HTTPImageTransfer', 'totalSourceBytes': 331, 'totalDestinationBytes': 1476, 'totalDestinationPackets': 2, 'totalSourcePackets': 4, 'sourcePayloadAsBase64': None, 'sourcePayloadAsUTF': None, 'destinationPayloadAsBase64': None, 'destinationPayloadAsUTF': None, 'direction': 'L2R', 'sourceTCPFlagsDescription': 'F,P,A', 'destinationTCPFlagsDescription': 'F,P,A', 'source': '192.168.4.119', 'protocolName': 'tcp_ip', 'sourcePort': 3642, 'destination': '142.166.14.86', 'destinationPort': 80, 'startDateTime': '6/13/2010 23:58', 'stopDateTime': '6/14/2010 0:01', 'Label': 'Normal'}, {'generated': '3/11/2014 18:21', 'appName': 'HTTPWeb', 'totalSourceBytes': 64, 'totalDestinationBytes': 0, 'totalDestinationPackets': 0, 'totalSourcePackets': 1, 'sourcePayloadAsBase64': None, 'sourcePayloadAsUTF': None, 'destinationPayloadAsBase64': None, 'destinationPayloadAsUTF': None, 'direction': 'L2R',  ...
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Check first few lines exactly as they are
with open('data/normal_traffic/benign_traffic_fixed.json', 'rt', encoding='utf-8') as f:
    for i in range(400):
        line = f.readline()
        #print(f"Line {i+1} (length={len(line)}):")
        print(repr(line))
        # print()
# Out:
# '[\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "Unknown_UDP",\n'
# '    "totalSourceBytes": 16076,\n'
# '    "totalDestinationBytes": 0,\n'
# '    "totalDestinationPackets": 0,\n'
# '    "totalSourcePackets": 178,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": null,\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "192.168.5.122",\n'
# '    "protocolName": "udp_ip",\n'
# '    "sourcePort": 5353,\n'
# '    "destination": "224.0.0.251",\n'
# '    "destinationPort": 5353,\n'
# '    "startDateTime": "6/13/2010 23:57",\n'
# '    "stopDateTime": "6/14/2010 0:11",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPImageTransfer",\n'
# '    "totalSourceBytes": 384,\n'
# '    "totalDestinationBytes": 0,\n'
# '    "totalDestinationPackets": 0,\n'
# '    "totalSourcePackets": 6,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,A",\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "192.168.2.111",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 4435,\n'
# '    "destination": "206.217.198.186",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/14/2010 0:01",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "DNS",\n'
# '    "totalSourceBytes": 171,\n'
# '    "totalDestinationBytes": 642,\n'
# '    "totalDestinationPackets": 4,\n'
# '    "totalSourcePackets": 2,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2L",\n'
# '    "sourceTCPFlagsDescription": null,\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "192.168.4.119",\n'
# '    "protocolName": "udp_ip",\n'
# '    "sourcePort": 4428,\n'
# '    "destination": "192.168.5.122",\n'
# '    "destinationPort": 53,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPImageTransfer",\n'
# '    "totalSourceBytes": 384,\n'
# '    "totalDestinationBytes": 0,\n'
# '    "totalDestinationPackets": 0,\n'
# '    "totalSourcePackets": 6,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,A",\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "192.168.4.119",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 3639,\n'
# '    "destination": "219.94.203.105",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/14/2010 0:00",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPImageTransfer",\n'
# '    "totalSourceBytes": 186,\n'
# '    "totalDestinationBytes": 128,\n'
# '    "totalDestinationPackets": 2,\n'
# '    "totalSourcePackets": 2,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,P,A",\n'
# '    "destinationTCPFlagsDescription": "R",\n'
# '    "source": "192.168.4.119",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 3641,\n'
# '    "destination": "98.137.80.50",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPImageTransfer",\n'
# '    "totalSourceBytes": 331,\n'
# '    "totalDestinationBytes": 1476,\n'
# '    "totalDestinationPackets": 2,\n'
# '    "totalSourcePackets": 4,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,P,A",\n'
# '    "destinationTCPFlagsDescription": "F,P,A",\n'
# '    "source": "192.168.4.119",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 3642,\n'
# '    "destination": "142.166.14.86",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/14/2010 0:01",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPWeb",\n'
# '    "totalSourceBytes": 64,\n'
# '    "totalDestinationBytes": 0,\n'
# '    "totalDestinationPackets": 0,\n'
# '    "totalSourcePackets": 1,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "R",\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "192.168.2.109",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 1523,\n'
# '    "destination": "59.106.19.74",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "SecureWeb",\n'
# '    "totalSourceBytes": 128,\n'
# '    "totalDestinationBytes": 128,\n'
# '    "totalDestinationPackets": 2,\n'
# '    "totalSourcePackets": 2,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,A",\n'
# '    "destinationTCPFlagsDescription": "F,A",\n'
# '    "source": "192.168.4.121",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 52031,\n'
# '    "destination": "209.87.178.183",\n'
# '    "destinationPort": 443,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/14/2010 0:00",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPWeb",\n'
# '    "totalSourceBytes": 128,\n'
# '    "totalDestinationBytes": 128,\n'
# '    "totalDestinationPackets": 2,\n'
# '    "totalSourcePackets": 2,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,A",\n'
# '    "destinationTCPFlagsDescription": "F,A",\n'
# '    "source": "192.168.4.121",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 52032,\n'
# '    "destination": "208.89.13.133",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/14/2010 0:00",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "Unknown_UDP",\n'
# '    "totalSourceBytes": 0,\n'
# '    "totalDestinationBytes": 465,\n'
# '    "totalDestinationPackets": 3,\n'
# '    "totalSourcePackets": 0,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "R2R",\n'
# '    "sourceTCPFlagsDescription": null,\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "0.0.0.0",\n'
# '    "protocolName": "udp_ip",\n'
# '    "sourcePort": 546,\n'
# '    "destination": "0.0.0.0",\n'
# '    "destinationPort": 547,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPWeb",\n'
# '    "totalSourceBytes": 256,\n'
# '    "totalDestinationBytes": 0,\n'
# '    "totalDestinationPackets": 0,\n'
# '    "totalSourcePackets": 4,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,A",\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "192.168.2.111",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 4431,\n'
# '    "destination": "69.163.132.48",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/14/2010 0:00",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "HTTPWeb",\n'
# '    "totalSourceBytes": 128,\n'
# '    "totalDestinationBytes": 0,\n'
# '    "totalDestinationPackets": 0,\n'
# '    "totalSourcePackets": 2,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2R",\n'
# '    "sourceTCPFlagsDescription": "F,A",\n'
# '    "destinationTCPFlagsDescription": null,\n'
# '    "source": "192.168.2.111",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 4429,\n'
# '    "destination": "69.163.132.48",\n'
# '    "destinationPort": 80,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "SSH",\n'
# '    "totalSourceBytes": 616,\n'
# '    "totalDestinationBytes": 1868,\n'
# '    "totalDestinationPackets": 20,\n'
# '    "totalSourcePackets": 6,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2L",\n'
# '    "sourceTCPFlagsDescription": "R,P,A",\n'
# '    "destinationTCPFlagsDescription": "P,A",\n'
# '    "source": "192.168.1.103",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 3259,\n'
# '    "destination": "192.168.5.122",\n'
# '    "destinationPort": 22,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "SSH",\n'
# '    "totalSourceBytes": 14274,\n'
# '    "totalDestinationBytes": 985220,\n'
# '    "totalDestinationPackets": 712,\n'
# '    "totalSourcePackets": 198,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2L",\n'
# '    "sourceTCPFlagsDescription": "R,P,A",\n'
# '    "destinationTCPFlagsDescription": "P,A",\n'
# '    "source": "192.168.1.102",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 3176,\n'
# '    "destination": "192.168.5.122",\n'
# '    "destinationPort": 22,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "POP",\n'
# '    "totalSourceBytes": 401,\n'
# '    "totalDestinationBytes": 974,\n'
# '    "totalDestinationPackets": 14,\n'
# '    "totalSourcePackets": 6,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2L",\n'
# '    "sourceTCPFlagsDescription": "F,P,A",\n'
# '    "destinationTCPFlagsDescription": "F,P,A",\n'
# '    "source": "192.168.4.120",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 2101,\n'
# '    "destination": "192.168.5.122",\n'
# '    "destinationPort": 110,\n'
# '    "startDateTime": "6/13/2010 23:58",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "SSH",\n'
# '    "totalSourceBytes": 2474,\n'
# '    "totalDestinationBytes": 7774,\n'
# '    "totalDestinationPackets": 50,\n'
# '    "totalSourcePackets": 20,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2L",\n'
# '    "sourceTCPFlagsDescription": "S,R,P,A",\n'
# '    "destinationTCPFlagsDescription": "S,P,A",\n'
# '    "source": "192.168.1.103",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 3260,\n'
# '    "destination": "192.168.5.122",\n'
# '    "destinationPort": 22,\n'
# '    "startDateTime": "6/13/2010 23:59",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "SSH",\n'
# '    "totalSourceBytes": 2970,\n'
# '    "totalDestinationBytes": 54810,\n'
# '    "totalDestinationPackets": 80,\n'
# '    "totalSourcePackets": 28,\n'
# '    "sourcePayloadAsBase64": null,\n'
# '    "sourcePayloadAsUTF": null,\n'
# '    "destinationPayloadAsBase64": null,\n'
# '    "destinationPayloadAsUTF": null,\n'
# '    "direction": "L2L",\n'
# '    "sourceTCPFlagsDescription": "S,R,P,A",\n'
# '    "destinationTCPFlagsDescription": "S,P,A",\n'
# '    "source": "192.168.1.102",\n'
# '    "protocolName": "tcp_ip",\n'
# '    "sourcePort": 3177,\n'
# '    "destination": "192.168.5.122",\n'
# '    "destinationPort": 22,\n'
# '    "startDateTime": "6/13/2010 23:59",\n'
# '    "stopDateTime": "6/13/2010 23:59",\n'
# '    "Label": "Normal"\n'
# '  },\n'
# '  {\n'
# '    "generated": "3/11/2014 18:21",\n'
# '    "appName": "SSH",\n'
# '    "totalSourceBytes": 1724,\n'
# '    "totalDestinationBytes": 6478,\n'
# '    "totalDestinationPackets": 42,\n'
# '    "totalSourcePackets": 15,\n'
# '    "sourcePayloadAsBase64": null,\n'

# %%
from df_initializer import DataFrameInitializer
from df_formatter import DataFrameFormatter
import pandas as pd


pd.set_option('display.max_columns', None)      # show all columns
pd.set_option('display.max_rows', None)         # show all rows
pd.set_option('display.width', None)            # disable wrapping
pd.set_option('display.max_colwidth', None)     # show full cell contents

df_initializer = DataFrameInitializer(
    cowrie_json='data/cowrie/log/cowrie.json',
    dionea_json='data/dionaea/log/dionaea.json',
    suricata_json='data/suricata/log/suricata.json',
)
cowrie_df, dionea_df, suricata_df = df_initializer.initialize_dfs()

df_formatter = DataFrameFormatter(cowrie_df, dionea_df, suricata_df)

df_formatter.cowrie_df[df_formatter.cowrie_df['session'] == 'e1eda165c927']
# Out:
# Index(['dst_ip', 'dst_port', 'src_hostname', 'src_ip', 'src_port', 'timestamp',
#        'ftp', 'credentials', 'protocol', 'transport', 'type'],
#       dtype='object')
#           session        source_ip destination_ip  source_port  \
# 429  e1eda165c927  103.177.227.135     172.29.0.2      36458.0
#
#      destination_port              timestamp_start  \
# 429              22.0  2025-10-24T03:10:38.935155Z
#
#                    timestamp_end transport_protocol application_protocol  \
# 429  2025-10-24T03:10:45.622710Z                tcp                  ssh
#
#     duration      label
# 429      6.7  malicious

# %%
df_formatter.dionea_df.head(10)
# Out:
#   destination_ip  destination_port src_hostname        source_ip  source_port  \
# 0  192.168.112.2               445                89.248.167.131        51706
# 1  192.168.112.2               445                89.248.167.131        51710
# 2  192.168.112.2               445                89.248.167.131        51724
# 3  192.168.112.2                21               185.247.137.203        44019
# 4  192.168.112.2                21                  80.82.77.202        60000
# 5  192.168.112.2                21                  103.203.59.5        35150
# 6  192.168.112.2               445               202.124.204.254        62747
# 7  192.168.112.2               445               202.124.204.254        62790
# 8  192.168.112.2               445                   1.55.223.39         3366
# 9  192.168.112.2               445                   1.55.223.39        30722
#
#                     timestamp application_protocol transport_protocol    type  \
# 0  2025-10-24T02:47:57.041581                 smbd                tcp  accept
# 1  2025-10-24T02:47:58.976812                 smbd                tcp  accept
# 2  2025-10-24T02:47:59.401482                 smbd                tcp  accept
# 3  2025-10-24T03:00:05.026478                 ftpd                tcp  accept
# 4  2025-10-24T03:20:54.523213                 ftpd                tcp  accept
# 5  2025-10-24T03:24:18.728484                 ftpd                tcp  accept
# 6  2025-10-24T03:33:01.243660                 smbd                tcp  accept
# 7  2025-10-24T03:33:04.644291                 smbd                tcp  accept
# 8  2025-10-24T03:35:34.384494                 smbd                tcp  accept
# 9  2025-10-24T03:35:34.788283                 smbd                tcp  accept
#
#        label
# 0  malicious
# 1  malicious
# 2  malicious
# 3  malicious
# 4  malicious
# 5  malicious
# 6  malicious
# 7  malicious
# 8  malicious
# 9  malicious

# %%
df_formatter.suricata_df.head(1)
# Out:
#                          timestamp       flow_id in_iface event_type  \
# 0  2025-10-24T02:44:06.405778+0000  1.742804e+15     ens4      alert
#
#        source_ip destination_ip transport_protocol  icmp_type  icmp_code  \
# 0  16.62.107.190     10.128.0.2               ICMP        8.0        0.0
#
#      pkt_src  \
# 0  wire/pcap
#
#                                                                                                                                                                                                                                                                                        alert  \
# 0  {'action': 'allowed', 'gid': 1, 'signature_id': 2100384, 'rev': 6, 'signature': 'GPL ICMP PING', 'category': 'Misc activity', 'severity': 3, 'metadata': {'confidence': ['Medium'], 'created_at': ['2010_09_23'], 'signature_severity': ['Informational'], 'updated_at': ['2019_07_26']}}
#
#    direction  \
# 0  to_server
#
#                                                                                                                                                                                   flow  \
# 0  {'pkts_toserver': 1, 'pkts_toclient': 0, 'bytes_toserver': 82, 'bytes_toclient': 0, 'start': '2025-10-24T02:44:06.405778+0000', 'src_ip': '16.62.107.190', 'dest_ip': '10.128.0.2'}
#
#                                                     payload  \
# 0  GHFNO0u3l6JdADiOxuVmH48Zx6noyuYsen52WfzUL7dZBuQ+th1JTg==
#
#                           payload_printable  stream  source_port  \
# 0  .qM;K...].8...f........,z~vY../.Y..>..IN     0.0          NaN
#
#    destination_port application_protocol metadata      label
# 0               NaN                  NaN      NaN  malicious

# %%
df_formatter.unite_all_dfs().head(2)
# Out:
#        source_ip destination_ip  source_port  destination_port  \
# 0  39.55.145.232     172.29.0.2      40332.0              23.0
# 1  39.55.145.232            NaN          NaN               NaN
#
#                      timestamp transport_protocol application_protocol  \
# 0  2025-10-24T02:51:30.093164Z                tcp               telnet
# 1  2025-10-24T02:53:30.193620Z                tcp                  NaN
#
#        label
# 0  malicious
# 1  malicious

# %% [markdown]
# # Cowrie dataframe

# %%
cowrie_df.head()
# Out:
#                   eventid           src_ip  src_port      dst_ip  dst_port  \
# 0  cowrie.session.connect    39.55.145.232   40332.0  172.29.0.2      23.0
# 1   cowrie.session.closed    39.55.145.232       NaN         NaN       NaN
# 2  cowrie.session.connect  186.137.131.237    2899.0  172.29.0.2      23.0
# 3   cowrie.session.closed  186.137.131.237       NaN         NaN       NaN
# 4  cowrie.session.connect  103.177.227.135   40520.0  172.29.0.2      22.0
#
#         session protocol  \
# 0  fc324807ccdb   telnet
# 1  fc324807ccdb      NaN
# 2  f63710ee4170   telnet
# 3  f63710ee4170      NaN
# 4  bdc1ef22d413      ssh
#
#                                                                          message  \
# 0    New connection: 39.55.145.232:40332 (172.29.0.2:23) [session: fc324807ccdb]
# 1                                              Connection lost after 120 seconds
# 2   New connection: 186.137.131.237:2899 (172.29.0.2:23) [session: f63710ee4170]
# 3                                               Connection lost after 14 seconds
# 4  New connection: 103.177.227.135:40520 (172.29.0.2:22) [session: bdc1ef22d413]
#
#          sensor                    timestamp    duration version hassh  \
# 0  37e2115ebaeb  2025-10-24T02:51:30.093164Z         NaN     NaN   NaN
# 1  37e2115ebaeb  2025-10-24T02:53:30.193620Z  120.100592     NaN   NaN
# 2  37e2115ebaeb  2025-10-24T03:01:30.276055Z         NaN     NaN   NaN
# 3  37e2115ebaeb  2025-10-24T03:01:44.470786Z   14.194879     NaN   NaN
# 4  37e2115ebaeb  2025-10-24T03:07:36.862724Z         NaN     NaN   NaN
#
#   hasshAlgorithms kexAlgs keyAlgs encCS macCS compCS langCS username password  \
# 0             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 1             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 2             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 3             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 4             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
#
#   arch input ttylog  size shasum duplicate data  id
# 0  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 1  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 2  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 3  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 4  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN

# %% [markdown]
# # Dionea Dataframe

# %%
dionea_df.head()
# Out:
#                                                    connection         dst_ip  \
# 0  {'protocol': 'smbd', 'transport': 'tcp', 'type': 'accept'}  192.168.112.2
# 1  {'protocol': 'smbd', 'transport': 'tcp', 'type': 'accept'}  192.168.112.2
# 2  {'protocol': 'smbd', 'transport': 'tcp', 'type': 'accept'}  192.168.112.2
# 3  {'protocol': 'ftpd', 'transport': 'tcp', 'type': 'accept'}  192.168.112.2
# 4  {'protocol': 'ftpd', 'transport': 'tcp', 'type': 'accept'}  192.168.112.2
#
#    dst_port src_hostname           src_ip  src_port  \
# 0       445                89.248.167.131     51706
# 1       445                89.248.167.131     51710
# 2       445                89.248.167.131     51724
# 3        21               185.247.137.203     44019
# 4        21                  80.82.77.202     60000
#
#                     timestamp  \
# 0  2025-10-24T02:47:57.041581
# 1  2025-10-24T02:47:58.976812
# 2  2025-10-24T02:47:59.401482
# 3  2025-10-24T03:00:05.026478
# 4  2025-10-24T03:20:54.523213
#
#                                                                                           ftp  \
# 0                                                                                         NaN
# 1                                                                                         NaN
# 2                                                                                         NaN
# 3  {'commands': {'arguments': ['', '', '', ''], 'command': ['HELP', 'SYST', 'FEAT', 'QUIT']}}
# 4                                   {'commands': {'arguments': ['TLS'], 'command': ['AUTH']}}
#
#   credentials
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# # Suricata Dataframe

# %%
suricata_df.head()
# Out:
#                          timestamp       flow_id in_iface event_type  \
# 0  2025-10-24T02:44:06.405778+0000  1.742804e+15     ens4      alert
# 1  2025-10-24T02:44:07.619878+0000  2.096864e+15     ens4      alert
# 2  2025-10-24T02:44:07.623239+0000  2.101217e+15     ens4        tls
# 3  2025-10-24T02:44:08.117768+0000  2.238090e+14     ens4      alert
# 4  2025-10-24T02:44:08.118390+0000  2.238090e+14     ens4      alert
#
#             src_ip         dest_ip proto  icmp_type  icmp_code    pkt_src  \
# 0    16.62.107.190      10.128.0.2  ICMP        8.0        0.0  wire/pcap
# 1  169.254.169.254      10.128.0.2   UDP        NaN        NaN  wire/pcap
# 2       10.128.0.2  216.239.34.174   TCP        NaN        NaN  wire/pcap
# 3       10.128.0.2  216.239.34.174   TCP        NaN        NaN  wire/pcap
# 4   216.239.34.174      10.128.0.2   TCP        NaN        NaN  wire/pcap
#
#    ... anomaly  ssh tftp tx_guessed app_proto_orig  snmp  rfb  app_proto_ts  \
# 0  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 1  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 2  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 3  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 4  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
#
#   pgsql smtp
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# # Tanner Dataframe

# %%
tanner_df.head()
# Out:
#   method                                               path  \
# 0    GET                        /cgi-bin/luci/;stok=/locale
# 1    GET                                                  /
# 2    GET                                                  /
# 3    GET                                                  /
# 4   POST  /cgi-bin/.%2e/.%2e/.%2e/.%2e/.%2e/.%2e/.%2e/.%...
#
#                                              headers  \
# 0  {'host': '35.225.86.61:80', 'connection': 'clo...
# 1  {'host': '35.225.86.61', 'user-agent': 'Mozill...
# 2  {'user-agent': 'Hello from Palo Alto Networks,...
# 3  {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; ...
# 4  {'host': '35.225.86.61:80', 'accept': '*/*', '...
#
#                                    uuid  \
# 0  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 1  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 2  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 3  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 4  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
#
#                                       peer  status              cookies  \
# 0  {'ip': '193.142.147.209', 'port': 1358}     200  {'sess_uuid': None}
# 1  {'ip': '149.100.11.243', 'port': 42870}     200  {'sess_uuid': None}
# 2  {'ip': '205.210.31.183', 'port': 53880}     200  {'sess_uuid': None}
# 3  {'ip': '204.76.203.212', 'port': 55968}     200  {'sess_uuid': None}
# 4   {'ip': '142.93.132.14', 'port': 53978}     200  {'sess_uuid': None}
#
#                                         response_msg  \
# 0  {'version': '0.6.0', 'response': {'message': {...
# 1  {'version': '0.6.0', 'response': {'message': {...
# 2  {'version': '0.6.0', 'response': {'message': {...
# 3  {'version': '0.6.0', 'response': {'message': {...
# 4  {'version': '0.6.0', 'response': {'message': {...
#
#                     timestamp post_data
# 0  2025-10-24T02:57:02.021400       NaN
# 1  2025-10-24T02:58:36.860069       NaN
# 2  2025-10-24T03:00:26.628714       NaN
# 3  2025-10-24T03:21:31.705012       NaN
# 4  2025-10-24T03:28:41.977489        {}

# %% [markdown]
# # Collective analisys

# %% [markdown]
# ### Exploration

# %%
print("Cowrie Columns:", cowrie_df.columns)
print("Dionea Columns:", dionea_df.columns)
print("Suricata Columns:", suricata_df.columns)
print("Tanner Columns:", tanner_df.columns)
# Out:
# Cowrie Columns: Index(['eventid', 'src_ip', 'src_port', 'dst_ip', 'dst_port', 'session',
#        'protocol', 'message', 'sensor', 'timestamp', 'duration', 'version',
#        'hassh', 'hasshAlgorithms', 'kexAlgs', 'keyAlgs', 'encCS', 'macCS',
#        'compCS', 'langCS', 'username', 'password', 'arch', 'input', 'ttylog',
#        'size', 'shasum', 'duplicate', 'data', 'id'],
#       dtype='object')
# Dionea Columns: Index(['connection', 'dst_ip', 'dst_port', 'src_hostname', 'src_ip',
#        'src_port', 'timestamp', 'ftp', 'credentials'],
#       dtype='object')
# Suricata Columns: Index(['timestamp', 'flow_id', 'in_iface', 'event_type', 'src_ip', 'dest_ip',
#        'proto', 'icmp_type', 'icmp_code', 'pkt_src', 'alert', 'direction',
#        'flow', 'payload', 'payload_printable', 'stream', 'src_port',
#        'dest_port', 'app_proto', 'metadata', 'tls', 'tx_id', 'http',
#        'fileinfo', 'tcp', 'smb', 'response_icmp_type', 'response_icmp_code',
#        'sip', 'files', 'app_proto_tc', 'anomaly', 'ssh', 'tftp', 'tx_guessed',
#        'app_proto_orig', 'snmp', 'rfb', 'app_proto_ts', 'pgsql', 'smtp'],
#       dtype='object')
# Tanner Columns: Index(['method', 'path', 'headers', 'uuid', 'peer', 'status', 'cookies',
#        'response_msg', 'timestamp', 'post_data'],
#       dtype='object')

# %%
df_filtered = suricata_df[(suricata_df["tcp"].notnull())]
print(df_filtered[["timestamp", "src_ip", "dest_ip", "tcp"]])

print(suricata_df["tcp"].notnull().sum())
print(suricata_df["http"].notnull().sum())
print(suricata_df["tls"].notnull().sum())
print(suricata_df["smb"].notnull().sum())
print(suricata_df["sip"].notnull().sum())
# Out:
#                              timestamp      src_ip          dest_ip  \
# 1705   2025-10-24T02:45:12.986416+0000  10.128.0.2   216.239.34.174
# 1708   2025-10-24T02:45:20.948560+0000  10.128.0.2   216.239.34.174
# 1709   2025-10-24T02:45:20.948660+0000  10.128.0.2   216.239.34.174
# 1712   2025-10-24T02:45:24.932398+0000  10.128.0.2   216.239.34.174
# 1716   2025-10-24T02:45:26.993191+0000  10.128.0.2  192.178.129.207
# ...                                ...         ...              ...
# 71555  2025-10-24T13:13:20.114401+0000  10.128.0.2    74.125.132.95
# 71560  2025-10-24T13:13:21.038314+0000  10.128.0.2     91.189.91.82
# 71562  2025-10-24T13:13:21.059437+0000  10.128.0.2  173.194.206.100
# 71574  2025-10-24T13:13:23.064853+0000  10.128.0.2   216.239.38.174
# 71597  2025-10-24T13:13:27.042830+0000  10.128.0.2   216.239.38.174
#
#                                                      tcp
# 1705   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1708   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1709   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1712   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1716   {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# ...                                                  ...
# 71555  {'tcp_flags': '1f', 'tcp_flags_ts': '1f', 'tcp...
# 71560  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# 71562  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# 71574  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# 71597  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
#
# [13834 rows x 4 columns]
# 13834
# 2179
# 5754
# 12334
# 134

# %%
suricata_df.count()
# Out:
# timestamp             71679
# flow_id               69082
# in_iface              71679
# event_type            71679
# src_ip                69083
# dest_ip               69083
# proto                 69083
# icmp_type             14857
# icmp_code             14857
# pkt_src               47171
# alert                 26981
# direction             24384
# flow                  48892
# payload               20430
# payload_printable     24385
# stream                24385
# src_port              54226
# dest_port             54226
# app_proto             33185
# metadata              19980
# tls                    5754
# tx_id                  6874
# http                   2179
# fileinfo                539
# tcp                   13834
# smb                   12334
# response_icmp_type     2798
# response_icmp_code     2798
# sip                     134
# files                   240
# app_proto_tc            107
# anomaly                 126
# ssh                     373
# tftp                      5
# tx_guessed             4783
# app_proto_orig            8
# snmp                     72
# rfb                       4
# app_proto_ts             29
# pgsql                     5
# smtp                      4
# dtype: int64

# %% [markdown]
# ### Timestamp

# %%
import pandas as pd
pd.set_option('display.max_columns', None)       # show all columns

cowrie_df[['eventid', 'src_ip', 'src_port', 'dst_ip', 'dst_port', 'session', 'protocol', 'message', 'sensor', 'timestamp', 'duration', 'version', 'hassh', 'hasshAlgorithms', 'kexAlgs', 'keyAlgs', 'encCS', 'macCS', 'compCS', 'langCS', 'username', 'password', 'arch', 'input', 'ttylog', 'size', 'shasum', 'duplicate', 'data', 'id']].head()
# Out:
#                   eventid           src_ip  src_port      dst_ip  dst_port  \
# 0  cowrie.session.connect    39.55.145.232   40332.0  172.29.0.2      23.0
# 1   cowrie.session.closed    39.55.145.232       NaN         NaN       NaN
# 2  cowrie.session.connect  186.137.131.237    2899.0  172.29.0.2      23.0
# 3   cowrie.session.closed  186.137.131.237       NaN         NaN       NaN
# 4  cowrie.session.connect  103.177.227.135   40520.0  172.29.0.2      22.0
#
#         session protocol                                            message  \
# 0  fc324807ccdb   telnet  New connection: 39.55.145.232:40332 (172.29.0....
# 1  fc324807ccdb      NaN                  Connection lost after 120 seconds
# 2  f63710ee4170   telnet  New connection: 186.137.131.237:2899 (172.29.0...
# 3  f63710ee4170      NaN                   Connection lost after 14 seconds
# 4  bdc1ef22d413      ssh  New connection: 103.177.227.135:40520 (172.29....
#
#          sensor                    timestamp    duration version hassh  \
# 0  37e2115ebaeb  2025-10-24T02:51:30.093164Z         NaN     NaN   NaN
# 1  37e2115ebaeb  2025-10-24T02:53:30.193620Z  120.100592     NaN   NaN
# 2  37e2115ebaeb  2025-10-24T03:01:30.276055Z         NaN     NaN   NaN
# 3  37e2115ebaeb  2025-10-24T03:01:44.470786Z   14.194879     NaN   NaN
# 4  37e2115ebaeb  2025-10-24T03:07:36.862724Z         NaN     NaN   NaN
#
#   hasshAlgorithms kexAlgs keyAlgs encCS macCS compCS langCS username password  \
# 0             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 1             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 2             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 3             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
# 4             NaN     NaN     NaN   NaN   NaN    NaN    NaN      NaN      NaN
#
#   arch input ttylog  size shasum duplicate data  id
# 0  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 1  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 2  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 3  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN
# 4  NaN   NaN    NaN   NaN    NaN       NaN  NaN NaN

# %%
dionea_df[["timestamp", "src_ip", "dst_ip"]]
# Out:
#                                              connection         dst_ip  \
# 0     {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
# 1     {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
# 2     {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
# 3     {'protocol': 'ftpd', 'transport': 'tcp', 'type...  192.168.112.2
# 4     {'protocol': 'ftpd', 'transport': 'tcp', 'type...  192.168.112.2
# ...                                                 ...            ...
# 6282  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
# 6283  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
# 6284  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
# 6285  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
# 6286  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2
#
#       dst_port src_hostname           src_ip  src_port  \
# 0          445                89.248.167.131     51706
# 1          445                89.248.167.131     51710
# 2          445                89.248.167.131     51724
# 3           21               185.247.137.203     44019
# 4           21                  80.82.77.202     60000
# ...        ...          ...              ...       ...
# 6282       445                181.115.193.18     56476
# 6283       445                181.115.193.18     56485
# 6284       445                  223.4.205.37      2722
# 6285       445                  223.4.205.37      2783
# 6286       445                181.115.193.18     56962
#
#                        timestamp
# 0     2025-10-24T02:47:57.041581
# 1     2025-10-24T02:47:58.976812
# 2     2025-10-24T02:47:59.401482
# 3     2025-10-24T03:00:05.026478
# 4     2025-10-24T03:20:54.523213
# ...                          ...
# 6282  2025-10-24T13:11:08.269532
# 6283  2025-10-24T13:11:08.444294
# 6284  2025-10-24T13:10:02.613979
# 6285  2025-10-24T13:10:02.725227
# 6286  2025-10-24T13:11:12.362302
#
# [6287 rows x 7 columns]

# %%
suricata_df[['timestamp', 'flow_id', 'in_iface', 'event_type', 'src_ip', 'dest_ip', 'proto', 'icmp_type', 'icmp_code', 'pkt_src', 'alert', 'direction', 'flow', 'payload', 'payload_printable', 'stream', 'src_port', 'dest_port', 'app_proto', 'metadata', 'tls', 'tx_id', 'http', 'fileinfo', 'tcp', 'smb', 'response_icmp_type', 'response_icmp_code', 'sip', 'files', 'app_proto_tc', 'anomaly', 'ssh', 'tftp', 'tx_guessed', 'app_proto_orig', 'snmp', 'rfb', 'app_proto_ts', 'pgsql', 'smtp']].head()
# Out:
#                          timestamp       flow_id in_iface event_type  \
# 0  2025-10-24T02:44:06.405778+0000  1.742804e+15     ens4      alert
# 1  2025-10-24T02:44:07.619878+0000  2.096864e+15     ens4      alert
# 2  2025-10-24T02:44:07.623239+0000  2.101217e+15     ens4        tls
# 3  2025-10-24T02:44:08.117768+0000  2.238090e+14     ens4      alert
# 4  2025-10-24T02:44:08.118390+0000  2.238090e+14     ens4      alert
#
#             src_ip         dest_ip proto  icmp_type  icmp_code    pkt_src  \
# 0    16.62.107.190      10.128.0.2  ICMP        8.0        0.0  wire/pcap
# 1  169.254.169.254      10.128.0.2   UDP        NaN        NaN  wire/pcap
# 2       10.128.0.2  216.239.34.174   TCP        NaN        NaN  wire/pcap
# 3       10.128.0.2  216.239.34.174   TCP        NaN        NaN  wire/pcap
# 4   216.239.34.174      10.128.0.2   TCP        NaN        NaN  wire/pcap
#
#                                                alert  direction  \
# 0  {'action': 'allowed', 'gid': 1, 'signature_id'...  to_server
# 1  {'action': 'allowed', 'gid': 1, 'signature_id'...  to_client
# 2                                                NaN        NaN
# 3  {'action': 'allowed', 'gid': 1, 'signature_id'...  to_server
# 4  {'action': 'allowed', 'gid': 1, 'signature_id'...  to_client
#
#                                                 flow  \
# 0  {'pkts_toserver': 1, 'pkts_toclient': 0, 'byte...
# 1  {'pkts_toserver': 2, 'pkts_toclient': 1, 'byte...
# 2                                                NaN
# 3  {'pkts_toserver': 2, 'pkts_toclient': 0, 'byte...
# 4  {'pkts_toserver': 2, 'pkts_toclient': 1, 'byte...
#
#                                              payload  \
# 0  GHFNO0u3l6JdADiOxuVmH48Zx6noyuYsen52WfzUL7dZBu...
# 1  a1yBgAABAAUAAAAAB2xvZ2dpbmcKZ29vZ2xlYXBpcwNjb2...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    payload_printable  stream  src_port  \
# 0           .qM;K...].8...f........,z~vY../.Y..>..IN     0.0       NaN
# 1  k\...........logging\ngoogleapis.com.............     0.0      53.0
# 2                                                NaN     NaN   59728.0
# 3                                                        0.0   53790.0
# 4                                                        0.0     443.0
#
#    dest_port app_proto                                           metadata  \
# 0        NaN       NaN                                                NaN
# 1    36113.0    failed                                                NaN
# 2      443.0       NaN  {'flowbits': ['FB180732_0', 'BS.SSL.Known.Port']}
# 3      443.0       NaN                                                NaN
# 4    53790.0       NaN                                                NaN
#
#                                                  tls  tx_id http fileinfo  \
# 0                                                NaN    NaN  NaN      NaN
# 1                                                NaN    NaN  NaN      NaN
# 2  {'sni': 'logging.googleapis.com', 'version': '...    NaN  NaN      NaN
# 3                                                NaN    NaN  NaN      NaN
# 4                                                NaN    NaN  NaN      NaN
#
#    tcp  smb  response_icmp_type  response_icmp_code  sip files app_proto_tc  \
# 0  NaN  NaN                 NaN                 NaN  NaN   NaN          NaN
# 1  NaN  NaN                 NaN                 NaN  NaN   NaN          NaN
# 2  NaN  NaN                 NaN                 NaN  NaN   NaN          NaN
# 3  NaN  NaN                 NaN                 NaN  NaN   NaN          NaN
# 4  NaN  NaN                 NaN                 NaN  NaN   NaN          NaN
#
#   anomaly  ssh tftp tx_guessed app_proto_orig snmp  rfb app_proto_ts pgsql  \
# 0     NaN  NaN  NaN        NaN            NaN  NaN  NaN          NaN   NaN
# 1     NaN  NaN  NaN        NaN            NaN  NaN  NaN          NaN   NaN
# 2     NaN  NaN  NaN        NaN            NaN  NaN  NaN          NaN   NaN
# 3     NaN  NaN  NaN        NaN            NaN  NaN  NaN          NaN   NaN
# 4     NaN  NaN  NaN        NaN            NaN  NaN  NaN          NaN   NaN
#
#   smtp
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
tanner_df[["timestamp", "peer", "method"]]
# Out:
#                       timestamp                                     peer  \
# 0    2025-10-24T02:57:02.021400  {'ip': '193.142.147.209', 'port': 1358}
# 1    2025-10-24T02:58:36.860069  {'ip': '149.100.11.243', 'port': 42870}
# 2    2025-10-24T03:00:26.628714  {'ip': '205.210.31.183', 'port': 53880}
# 3    2025-10-24T03:21:31.705012  {'ip': '204.76.203.212', 'port': 55968}
# 4    2025-10-24T03:28:41.977489   {'ip': '142.93.132.14', 'port': 53978}
# ..                          ...                                      ...
# 189  2025-10-24T12:42:21.086106  {'ip': '204.76.203.212', 'port': 42854}
# 190  2025-10-24T12:48:37.508286   {'ip': '79.124.40.174', 'port': 42824}
# 191  2025-10-24T13:01:48.089930   {'ip': '79.124.40.174', 'port': 44128}
# 192  2025-10-24T13:05:29.034801  {'ip': '204.76.203.219', 'port': 53530}
# 193  2025-10-24T13:10:42.151909   {'ip': '79.124.40.174', 'port': 57232}
#
#     method
# 0      GET
# 1      GET
# 2      GET
# 3      GET
# 4     POST
# ..     ...
# 189    GET
# 190    GET
# 191    GET
# 192    GET
# 193   POST
#
# [194 rows x 3 columns]
