# %%
from df_initializer import DataFrameInitializer

df_initializer = DataFrameInitializer(
    cowrie_json='data/cowrie/log/cowrie.json',
    dionea_json='data/dionaea/log/dionaea.json',
    suricata_json='data/suricata/log/suricata.json',
    tanner_json='data/tanner/log/tanner.json'
)
cowrie_df, dionea_df, suricata_df, tanner_df = df_initializer.initialize_dfs()

# %% [markdown]
# # Cowrie dataframe

# %%
cowrie_df.head()
# Out:
#                   eventid           src_ip  src_port      dst_ip  dst_port  \
# 0  cowrie.session.connect    39.55.145.232   40332.0  172.29.0.2      23.0
# 1   cowrie.session.closed    39.55.145.232       NaN         NaN       NaN
# 2  cowrie.session.connect  186.137.131.237    2899.0  172.29.0.2      23.0
# 3   cowrie.session.closed  186.137.131.237       NaN         NaN       NaN
# 4  cowrie.session.connect  103.177.227.135   40520.0  172.29.0.2      22.0
#
#         session protocol                                            message  \
# 0  fc324807ccdb   telnet  New connection: 39.55.145.232:40332 (172.29.0....
# 1  fc324807ccdb      NaN                  Connection lost after 120 seconds
# 2  f63710ee4170   telnet  New connection: 186.137.131.237:2899 (172.29.0...
# 3  f63710ee4170      NaN                   Connection lost after 14 seconds
# 4  bdc1ef22d413      ssh  New connection: 103.177.227.135:40520 (172.29....
#
#          sensor                    timestamp  ... username password arch  \
# 0  37e2115ebaeb  2025-10-24T02:51:30.093164Z  ...      NaN      NaN  NaN
# 1  37e2115ebaeb  2025-10-24T02:53:30.193620Z  ...      NaN      NaN  NaN
# 2  37e2115ebaeb  2025-10-24T03:01:30.276055Z  ...      NaN      NaN  NaN
# 3  37e2115ebaeb  2025-10-24T03:01:44.470786Z  ...      NaN      NaN  NaN
# 4  37e2115ebaeb  2025-10-24T03:07:36.862724Z  ...      NaN      NaN  NaN
#
#   input ttylog size shasum duplicate data  id
# 0   NaN    NaN  NaN    NaN       NaN  NaN NaN
# 1   NaN    NaN  NaN    NaN       NaN  NaN NaN
# 2   NaN    NaN  NaN    NaN       NaN  NaN NaN
# 3   NaN    NaN  NaN    NaN       NaN  NaN NaN
# 4   NaN    NaN  NaN    NaN       NaN  NaN NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Dionea Dataframe

# %%
dionea_df.head()
# Out:
#                                           connection         dst_ip  dst_port  \
# 0  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2       445
# 1  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2       445
# 2  {'protocol': 'smbd', 'transport': 'tcp', 'type...  192.168.112.2       445
# 3  {'protocol': 'ftpd', 'transport': 'tcp', 'type...  192.168.112.2        21
# 4  {'protocol': 'ftpd', 'transport': 'tcp', 'type...  192.168.112.2        21
#
#   src_hostname           src_ip  src_port                   timestamp  \
# 0                89.248.167.131     51706  2025-10-24T02:47:57.041581
# 1                89.248.167.131     51710  2025-10-24T02:47:58.976812
# 2                89.248.167.131     51724  2025-10-24T02:47:59.401482
# 3               185.247.137.203     44019  2025-10-24T03:00:05.026478
# 4                  80.82.77.202     60000  2025-10-24T03:20:54.523213
#
#                                                  ftp credentials
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3  {'commands': {'arguments': ['', '', '', ''], '...         NaN
# 4  {'commands': {'arguments': ['TLS'], 'command':...         NaN

# %% [markdown]
# # Suricata Dataframe

# %%
suricata_df.head()
# Out:
#                          timestamp       flow_id in_iface event_type  \
# 0  2025-10-24T02:44:06.405778+0000  1.742804e+15     ens4      alert
# 1  2025-10-24T02:44:07.619878+0000  2.096864e+15     ens4      alert
# 2  2025-10-24T02:44:07.623239+0000  2.101217e+15     ens4        tls
# 3  2025-10-24T02:44:08.117768+0000  2.238090e+14     ens4      alert
# 4  2025-10-24T02:44:08.118390+0000  2.238090e+14     ens4      alert
#
#             src_ip         dest_ip proto  icmp_type  icmp_code    pkt_src  \
# 0    16.62.107.190      10.128.0.2  ICMP        8.0        0.0  wire/pcap
# 1  169.254.169.254      10.128.0.2   UDP        NaN        NaN  wire/pcap
# 2       10.128.0.2  216.239.34.174   TCP        NaN        NaN  wire/pcap
# 3       10.128.0.2  216.239.34.174   TCP        NaN        NaN  wire/pcap
# 4   216.239.34.174      10.128.0.2   TCP        NaN        NaN  wire/pcap
#
#    ... anomaly  ssh tftp tx_guessed app_proto_orig  snmp  rfb  app_proto_ts  \
# 0  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 1  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 2  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 3  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
# 4  ...     NaN  NaN  NaN        NaN            NaN   NaN  NaN           NaN
#
#   pgsql smtp
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# # Tanner Dataframe

# %%
tanner_df.head()
# Out:
#   method                                               path  \
# 0    GET                        /cgi-bin/luci/;stok=/locale
# 1    GET                                                  /
# 2    GET                                                  /
# 3    GET                                                  /
# 4   POST  /cgi-bin/.%2e/.%2e/.%2e/.%2e/.%2e/.%2e/.%2e/.%...
#
#                                              headers  \
# 0  {'host': '35.225.86.61:80', 'connection': 'clo...
# 1  {'host': '35.225.86.61', 'user-agent': 'Mozill...
# 2  {'user-agent': 'Hello from Palo Alto Networks,...
# 3  {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; ...
# 4  {'host': '35.225.86.61:80', 'accept': '*/*', '...
#
#                                    uuid  \
# 0  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 1  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 2  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 3  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
# 4  7e5880f3-f4fc-4ac6-b8f2-99cfa79a28b4
#
#                                       peer  status              cookies  \
# 0  {'ip': '193.142.147.209', 'port': 1358}     200  {'sess_uuid': None}
# 1  {'ip': '149.100.11.243', 'port': 42870}     200  {'sess_uuid': None}
# 2  {'ip': '205.210.31.183', 'port': 53880}     200  {'sess_uuid': None}
# 3  {'ip': '204.76.203.212', 'port': 55968}     200  {'sess_uuid': None}
# 4   {'ip': '142.93.132.14', 'port': 53978}     200  {'sess_uuid': None}
#
#                                         response_msg  \
# 0  {'version': '0.6.0', 'response': {'message': {...
# 1  {'version': '0.6.0', 'response': {'message': {...
# 2  {'version': '0.6.0', 'response': {'message': {...
# 3  {'version': '0.6.0', 'response': {'message': {...
# 4  {'version': '0.6.0', 'response': {'message': {...
#
#                     timestamp post_data
# 0  2025-10-24T02:57:02.021400       NaN
# 1  2025-10-24T02:58:36.860069       NaN
# 2  2025-10-24T03:00:26.628714       NaN
# 3  2025-10-24T03:21:31.705012       NaN
# 4  2025-10-24T03:28:41.977489        {}

# %% [markdown]
# # Collective analisys

# %% [markdown]
# ### Exploration

# %%
print("Cowrie Columns:", cowrie_df.columns)
print("Dionea Columns:", dionea_df.columns)
print("Suricata Columns:", suricata_df.columns)
print("Tanner Columns:", tanner_df.columns)
# Out:
# Cowrie Columns: Index(['eventid', 'src_ip', 'src_port', 'dst_ip', 'dst_port', 'session',
#        'protocol', 'message', 'sensor', 'timestamp', 'duration', 'version',
#        'hassh', 'hasshAlgorithms', 'kexAlgs', 'keyAlgs', 'encCS', 'macCS',
#        'compCS', 'langCS', 'username', 'password', 'arch', 'input', 'ttylog',
#        'size', 'shasum', 'duplicate', 'data', 'id'],
#       dtype='object')
# Dionea Columns: Index(['connection', 'dst_ip', 'dst_port', 'src_hostname', 'src_ip',
#        'src_port', 'timestamp', 'ftp', 'credentials'],
#       dtype='object')
# Suricata Columns: Index(['timestamp', 'flow_id', 'in_iface', 'event_type', 'src_ip', 'dest_ip',
#        'proto', 'icmp_type', 'icmp_code', 'pkt_src', 'alert', 'direction',
#        'flow', 'payload', 'payload_printable', 'stream', 'src_port',
#        'dest_port', 'app_proto', 'metadata', 'tls', 'tx_id', 'http',
#        'fileinfo', 'tcp', 'smb', 'response_icmp_type', 'response_icmp_code',
#        'sip', 'files', 'app_proto_tc', 'anomaly', 'ssh', 'tftp', 'tx_guessed',
#        'app_proto_orig', 'snmp', 'rfb', 'app_proto_ts', 'pgsql', 'smtp'],
#       dtype='object')
# Tanner Columns: Index(['method', 'path', 'headers', 'uuid', 'peer', 'status', 'cookies',
#        'response_msg', 'timestamp', 'post_data'],
#       dtype='object')

# %%
df_filtered = suricata_df[(suricata_df["tcp"].notnull())]
print(df_filtered[["timestamp", "src_ip", "dest_ip", "tcp"]])

print(suricata_df["tcp"].notnull().sum())
print(suricata_df["http"].notnull().sum())
print(suricata_df["tls"].notnull().sum())
print(suricata_df["smb"].notnull().sum())
print(suricata_df["sip"].notnull().sum())
# Out:
#                              timestamp      src_ip          dest_ip  \
# 1705   2025-10-24T02:45:12.986416+0000  10.128.0.2   216.239.34.174
# 1708   2025-10-24T02:45:20.948560+0000  10.128.0.2   216.239.34.174
# 1709   2025-10-24T02:45:20.948660+0000  10.128.0.2   216.239.34.174
# 1712   2025-10-24T02:45:24.932398+0000  10.128.0.2   216.239.34.174
# 1716   2025-10-24T02:45:26.993191+0000  10.128.0.2  192.178.129.207
# ...                                ...         ...              ...
# 71555  2025-10-24T13:13:20.114401+0000  10.128.0.2    74.125.132.95
# 71560  2025-10-24T13:13:21.038314+0000  10.128.0.2     91.189.91.82
# 71562  2025-10-24T13:13:21.059437+0000  10.128.0.2  173.194.206.100
# 71574  2025-10-24T13:13:23.064853+0000  10.128.0.2   216.239.38.174
# 71597  2025-10-24T13:13:27.042830+0000  10.128.0.2   216.239.38.174
#
#                                                      tcp
# 1705   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1708   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1709   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1712   {'tcp_flags': '00', 'tcp_flags_ts': '00', 'tcp...
# 1716   {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# ...                                                  ...
# 71555  {'tcp_flags': '1f', 'tcp_flags_ts': '1f', 'tcp...
# 71560  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# 71562  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# 71574  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
# 71597  {'tcp_flags': '1b', 'tcp_flags_ts': '1b', 'tcp...
#
# [13834 rows x 4 columns]
# 13834
# 2179
# 5754
# 12334
# 134

# %%
tanner_df.count()
# Out:
# method          194
# path            194
# headers         194
# uuid            194
# peer            194
# status          194
# cookies         194
# response_msg    194
# timestamp       194
# post_data        13
# dtype: int64

# %% [markdown]
# ### Timestamp

# %%
cowrie_df[["timestamp", "src_ip", "dst_ip"]]
# Out:
#                         timestamp           src_ip      dst_ip
# 0     2025-10-24T02:51:30.093164Z    39.55.145.232  172.29.0.2
# 1     2025-10-24T02:53:30.193620Z    39.55.145.232         NaN
# 2     2025-10-24T03:01:30.276055Z  186.137.131.237  172.29.0.2
# 3     2025-10-24T03:01:44.470786Z  186.137.131.237         NaN
# 4     2025-10-24T03:07:36.862724Z  103.177.227.135  172.29.0.2
# ...                           ...              ...         ...
# 2052  2025-10-24T13:10:31.108834Z  103.177.227.135  172.29.0.2
# 2053  2025-10-24T13:10:31.109695Z  103.177.227.135         NaN
# 2054  2025-10-24T13:10:31.383165Z  103.177.227.135         NaN
# 2055  2025-10-24T13:10:32.397585Z  103.177.227.135         NaN
# 2056  2025-10-24T13:10:33.781040Z  103.177.227.135         NaN
#
# [2057 rows x 3 columns]

# %%
dionea_df[["timestamp", "src_ip", "dst_ip"]]
# Out:
#                        timestamp           src_ip         dst_ip
# 0     2025-10-24T02:47:57.041581   89.248.167.131  192.168.112.2
# 1     2025-10-24T02:47:58.976812   89.248.167.131  192.168.112.2
# 2     2025-10-24T02:47:59.401482   89.248.167.131  192.168.112.2
# 3     2025-10-24T03:00:05.026478  185.247.137.203  192.168.112.2
# 4     2025-10-24T03:20:54.523213     80.82.77.202  192.168.112.2
# ...                          ...              ...            ...
# 6282  2025-10-24T13:11:08.269532   181.115.193.18  192.168.112.2
# 6283  2025-10-24T13:11:08.444294   181.115.193.18  192.168.112.2
# 6284  2025-10-24T13:10:02.613979     223.4.205.37  192.168.112.2
# 6285  2025-10-24T13:10:02.725227     223.4.205.37  192.168.112.2
# 6286  2025-10-24T13:11:12.362302   181.115.193.18  192.168.112.2
#
# [6287 rows x 3 columns]

# %%
suricata_df[["timestamp", "src_ip", "dest_ip"]]
# Out:
#                              timestamp           src_ip         dest_ip
# 0      2025-10-24T02:44:06.405778+0000    16.62.107.190      10.128.0.2
# 1      2025-10-24T02:44:07.619878+0000  169.254.169.254      10.128.0.2
# 2      2025-10-24T02:44:07.623239+0000       10.128.0.2  216.239.34.174
# 3      2025-10-24T02:44:08.117768+0000       10.128.0.2  216.239.34.174
# 4      2025-10-24T02:44:08.118390+0000   216.239.34.174      10.128.0.2
# ...                                ...              ...             ...
# 71674  2025-10-24T13:13:39.726376+0000   181.115.193.18      10.128.0.2
# 71675  2025-10-24T13:13:39.927284+0000   181.115.193.18      10.128.0.2
# 71676  2025-10-24T13:13:40.127414+0000   181.115.193.18      10.128.0.2
# 71677  2025-10-24T13:13:40.128181+0000   181.115.193.18      10.128.0.2
# 71678  2025-10-24T13:13:40.328282+0000   181.115.193.18      10.128.0.2
#
# [71679 rows x 3 columns]

# %%
tanner_df[["timestamp", "peer"]]
# Out:
#                       timestamp                                     peer
# 0    2025-10-24T02:57:02.021400  {'ip': '193.142.147.209', 'port': 1358}
# 1    2025-10-24T02:58:36.860069  {'ip': '149.100.11.243', 'port': 42870}
# 2    2025-10-24T03:00:26.628714  {'ip': '205.210.31.183', 'port': 53880}
# 3    2025-10-24T03:21:31.705012  {'ip': '204.76.203.212', 'port': 55968}
# 4    2025-10-24T03:28:41.977489   {'ip': '142.93.132.14', 'port': 53978}
# ..                          ...                                      ...
# 189  2025-10-24T12:42:21.086106  {'ip': '204.76.203.212', 'port': 42854}
# 190  2025-10-24T12:48:37.508286   {'ip': '79.124.40.174', 'port': 42824}
# 191  2025-10-24T13:01:48.089930   {'ip': '79.124.40.174', 'port': 44128}
# 192  2025-10-24T13:05:29.034801  {'ip': '204.76.203.219', 'port': 53530}
# 193  2025-10-24T13:10:42.151909   {'ip': '79.124.40.174', 'port': 57232}
#
# [194 rows x 2 columns]
